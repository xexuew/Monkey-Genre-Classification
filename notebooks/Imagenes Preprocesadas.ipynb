# %%
from os.path import join
import numpy as np
import configparser
import matplotlib.pyplot as plt
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('../config/config.ini')
# Out:
# ['../config/config.ini']

# %%
import sys
sys.path.insert(0, '../source/')
from Get_Train_Test_Data import GetTrainTestData

# %%
X_train, X_test,X_val, y_train, y_test, y_val = GetTrainTestData(config).readDataset()
# Out:
#   8%|▊         | 11/131 [00:00<00:01, 108.49it/s]
# Obteniendo..../input/n0
# 100%|██████████| 131/131 [00:01<00:00, 89.46it/s]
#   4%|▍         | 6/139 [00:00<00:02, 59.77it/s]
# Obteniendo..../input/n1
# 100%|██████████| 139/139 [00:01<00:00, 88.95it/s]
#  10%|█         | 14/137 [00:00<00:00, 138.60it/s]
# Obteniendo..../input/n2
# 100%|██████████| 137/137 [00:01<00:00, 92.97it/s]
#   2%|▏         | 3/152 [00:00<00:05, 26.57it/s]
# Obteniendo..../input/n3
# 100%|██████████| 152/152 [00:01<00:00, 87.50it/s]
#   8%|▊         | 10/131 [00:00<00:01, 95.19it/s]
# Obteniendo..../input/n4
# 100%|██████████| 131/131 [00:01<00:00, 75.43it/s]
#   7%|▋         | 10/141 [00:00<00:01, 99.18it/s]
# Obteniendo..../input/n5
# 100%|██████████| 141/141 [00:01<00:00, 81.01it/s]
#   6%|▌         | 8/132 [00:00<00:01, 77.02it/s]
# Obteniendo..../input/n6
# 100%|██████████| 132/132 [00:01<00:00, 101.68it/s]
#   5%|▍         | 7/142 [00:00<00:02, 66.98it/s]
# Obteniendo..../input/n7
# 100%|██████████| 142/142 [00:01<00:00, 91.90it/s]
#  11%|█         | 14/133 [00:00<00:00, 130.41it/s]
# Obteniendo..../input/n8
# 100%|██████████| 133/133 [00:01<00:00, 105.51it/s]
#  12%|█▏        | 16/130 [00:00<00:00, 151.89it/s]
# Obteniendo..../input/n9
# 100%|██████████| 130/130 [00:01<00:00, 98.19it/s]
# test-size = 0.25 Cambiar valor en config.py
# X_train Tamaño: (1026, 150, 150, 3) - X_test Tamaño: (171, 150, 150, 3) - X_val Tamaño: (171, 150, 150, 3)              - y_train Tamaño: (1026,) - y_test Tamaño: (171,) - y_val Tamaño: (171,)

# %%
labels = pd.read_csv(join(config['PATH_CONFIGURATION']['DATASET_PATH'], 'monkey_labels.txt'))
labels
# Out:
#    Label     Latin Name              Common Name                     \
# 0  n0         alouatta_palliata\t    mantled_howler
# 1  n1        erythrocebus_patas\t    patas_monkey
# 2  n2        cacajao_calvus\t        bald_uakari
# 3  n3        macaca_fuscata\t        japanese_macaque
# 4  n4       cebuella_pygmea\t        pygmy_marmoset
# 5  n5       cebus_capucinus\t        white_headed_capuchin
# 6  n6       mico_argentatus\t        silvery_marmoset
# 7  n7      saimiri_sciureus\t        common_squirrel_monkey
# 8  n8       aotus_nigriceps\t        black_headed_night_monkey
# 9  n9       trachypithecus_johnii    nilgiri_langur
#
#     Train Images    Validation Images
# 0             131                  26
# 1             139                  28
# 2             137                  27
# 3             152                  30
# 4             131                  26
# 5             141                  28
# 6             132                  26
# 7             142                  28
# 8             133                  27
# 9             132                  26

# %%
plt.figure(figsize=(20,10))
plt.subplot(321)
plt.imshow(X_train[1])

plt.subplot(322)
plt.imshow(X_train[2])

plt.subplot(323)
plt.imshow(X_train[3])

plt.subplot(324)
plt.imshow(X_train[4])

plt.subplot(325)
plt.imshow(X_train[5])

plt.subplot(326)
plt.imshow(X_train[6])

plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
